# %%
import torch
from torch.autograd import Variable
import numpy as np
import torch.nn.functional as F
import torchvision
from torchvision import transforms
import torch.optim as optim
from torch import nn
import matplotlib.pyplot as plt

# %%
class VAE(nn.Module):
  
    def __init__(self):
        super(VAE, self).__init__()
        
        self.fc1 = nn.Linear(28*28, 400)
        self.fc2_mu = nn.Linear(400, 20)
        self.fc2_sig = nn.Linear(400, 20)
        self.fc3 = nn.Linear(20, 400)
        self.fc4 = nn.Linear(400, 784)
  
    def encode(self,x):
        a1 = F.relu(self.fc1(x))
        a_mu = self.fc2_mu(a1)
        a_logvar = self.fc2_sig(a1)
        return a_mu, a_logvar
  
    def decode(self,z):
        a3 = F.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(a3))
  
    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return eps.mul(std).add_(mu)
  
    def forward(self,x):
        mu, logvar = self.encode(x.view(-1, 784))
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# %%
train_dataset = torchvision.datasets.MNIST(root='./data',train=True, transform=transforms.ToTensor(), download=True)
test_dataset = torchvision.datasets.MNIST(root='./data',train=False, transform=transforms.ToTensor(),download = True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,  batch_size=100, shuffle=False)

# %%
model = VAE()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
def loss_function(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')

    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD

# %%
num_epochs = 10
print_per = 100
model.train()
loss_record = []
for epoch in range(num_epochs):
    train_loss = 0
    print_loss = 0
    for i, (images, _) in enumerate(train_loader):
        images = images.reshape(-1, 28*28)
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(images)
        loss = loss_function(recon_batch, images, mu, logvar)
        loss.backward()
        if (epoch == 0):
            loss_record.append(loss.item())
        train_loss += loss.item()
        print_loss += loss.item()
        optimizer.step()
        
        if (i%print_per == 0):
            print("Epoch : {} , Minibatch : {} Loss = {:.4f}".format(epoch, i, print_loss))
#             loss_record.append(print_loss)
            print_loss = 0
    print("Epoch {} : Loss = ({:.4f}) ".format(epoch, train_loss))
# Out:
# Epoch : 0 , Minibatch : 0 Loss = 54842.3672
# Epoch : 0 , Minibatch : 100 Loss = 2304137.4062
# Epoch : 0 , Minibatch : 200 Loss = 1663926.5977
# Epoch : 0 , Minibatch : 300 Loss = 1474866.9746
# Epoch : 0 , Minibatch : 400 Loss = 1371451.0273
# Epoch : 0 , Minibatch : 500 Loss = 1310198.0762
# Epoch 0 : Loss = (9429043.6523)
# Epoch : 1 , Minibatch : 0 Loss = 12090.1846
# Epoch : 1 , Minibatch : 100 Loss = 1231670.5020
# Epoch : 1 , Minibatch : 200 Loss = 1209181.9268
# Epoch : 1 , Minibatch : 300 Loss = 1192662.6768
# Epoch : 1 , Minibatch : 400 Loss = 1173470.4834
# Epoch : 1 , Minibatch : 500 Loss = 1163669.7461
# Epoch 1 : Loss = (7124261.2109)
# Epoch : 2 , Minibatch : 0 Loss = 11217.5391
# Epoch : 2 , Minibatch : 100 Loss = 1142803.6377
# Epoch : 2 , Minibatch : 200 Loss = 1138537.7236
# Epoch : 2 , Minibatch : 300 Loss = 1125157.5508
# Epoch : 2 , Minibatch : 400 Loss = 1131272.3184
# Epoch : 2 , Minibatch : 500 Loss = 1114901.2979
# Epoch 2 : Loss = (6770788.4092)
# Epoch : 3 , Minibatch : 0 Loss = 10933.0020
# Epoch : 3 , Minibatch : 100 Loss = 1111127.4600
# Epoch : 3 , Minibatch : 200 Loss = 1113818.3076
# Epoch : 3 , Minibatch : 300 Loss = 1102622.9854
# Epoch : 3 , Minibatch : 400 Loss = 1098242.9277
# Epoch : 3 , Minibatch : 500 Loss = 1099818.6094
# Epoch 3 : Loss = (6623178.8359)
# Epoch : 4 , Minibatch : 0 Loss = 11040.1270
# Epoch : 4 , Minibatch : 100 Loss = 1097046.7471
# Epoch : 4 , Minibatch : 200 Loss = 1088404.1826
# Epoch : 4 , Minibatch : 300 Loss = 1090627.8389
# Epoch : 4 , Minibatch : 400 Loss = 1088425.8447
# Epoch : 4 , Minibatch : 500 Loss = 1088178.6357
# Epoch 4 : Loss = (6534485.1562)
# Epoch : 5 , Minibatch : 0 Loss = 10809.1914
# Epoch : 5 , Minibatch : 100 Loss = 1080788.5938
# Epoch : 5 , Minibatch : 200 Loss = 1080044.3027
# Epoch : 5 , Minibatch : 300 Loss = 1083000.0908
# Epoch : 5 , Minibatch : 400 Loss = 1080576.9756
# Epoch : 5 , Minibatch : 500 Loss = 1080380.1592
# Epoch 5 : Loss = (6480980.5029)
# Epoch : 6 , Minibatch : 0 Loss = 11193.9121
# Epoch : 6 , Minibatch : 100 Loss = 1073782.9316
# Epoch : 6 , Minibatch : 200 Loss = 1070875.1035
# Epoch : 6 , Minibatch : 300 Loss = 1072457.4648
# Epoch : 6 , Minibatch : 400 Loss = 1070300.5312
# Epoch : 6 , Minibatch : 500 Loss = 1075411.9326
# Epoch 6 : Loss = (6435337.6914)
# Epoch : 7 , Minibatch : 0 Loss = 10389.0742
# Epoch : 7 , Minibatch : 100 Loss = 1063533.3398
# Epoch : 7 , Minibatch : 200 Loss = 1069842.0430
# Epoch : 7 , Minibatch : 300 Loss = 1069467.2949
# Epoch : 7 , Minibatch : 400 Loss = 1066709.6182
# Epoch : 7 , Minibatch : 500 Loss = 1069046.0918
# Epoch 7 : Loss = (6401269.2666)
# Epoch : 8 , Minibatch : 0 Loss = 10617.1348
# Epoch : 8 , Minibatch : 100 Loss = 1065727.5869
# Epoch : 8 , Minibatch : 200 Loss = 1060531.0137
# Epoch : 8 , Minibatch : 300 Loss = 1063817.3691
# Epoch : 8 , Minibatch : 400 Loss = 1059977.6621
# Epoch : 8 , Minibatch : 500 Loss = 1061843.7959
# Epoch 8 : Loss = (6373824.2295)
# Epoch : 9 , Minibatch : 0 Loss = 10369.4258
# Epoch : 9 , Minibatch : 100 Loss = 1058725.9805
# Epoch : 9 , Minibatch : 200 Loss = 1059514.0361
# Epoch : 9 , Minibatch : 300 Loss = 1058505.7734
# Epoch : 9 , Minibatch : 400 Loss = 1059787.1523
# Epoch : 9 , Minibatch : 500 Loss = 1059445.8467
# Epoch 9 : Loss = (6354583.7314)

# %%
plt.plot(loss_record)

# %%
print(model(images)[0].data[0].numpy().shape)
image1 = images[8]
print(image1.shape)
plt.imshow(model(images)[0].data[8].numpy().reshape(28, 28), cmap='gray')
plt.show(block=True)
# Out:
# (784,)
# torch.Size([784])

# %%
test_loss = 0
print_per = 10
with torch.no_grad():
    for i, (images, _) in enumerate(test_loader):
        images = images.reshape(-1, 28*28)
        recon_batch, mu, logvar = model(images)
        test_loss += loss_function(recon_batch, images, mu, logvar).item()
        if (i%print_per == 0):
            plt.imshow(model(images)[0].data[0].numpy().reshape(28, 28), cmap='gray')
            plt.show(block=True)

# %%
image2 = images[1]
print(image2.shape)
# Out:
# torch.Size([784])

# %%
plt.imshow(model(images)[0].data[1].numpy().reshape(28, 28), cmap='gray')
plt.show(block=True)

# %%
plt.imshow(images[1].numpy().reshape(28, 28), cmap='gray')
plt.show(block=True)

# %%
with torch.no_grad():
    mu1, logvar1 = model.encode(image1)
    std1 = torch.exp(0.5*logvar1)
    mu2, logvar2 = model.encode(image2)
    std2 = torch.exp(0.5*logvar2)

# %%
with torch.no_grad():
    recon_images1 = []
    recon_images2 = []
    for ctr in range(0, 100, 5):
        eps_val = torch.full_like(mu1, fill_value = ctr * 0.01 )
        z_val1 = eps_val.mul(std1).add_(mu1)
        z_val2 = eps_val.mul(std2).add_(mu2)
        recon_image1 = model.decode(z_val1)
        recon_image2 = model.decode(z_val2)
        recon_images1.append(recon_image1)
        recon_images2.append(recon_image2)

# %%
print(recon_images1[0] - recon_images1[1])
# Out:
# tensor([ 2.2150e-08,  3.4394e-08,  4.9430e-08,  6.6235e-08,  4.5845e-08,
#          4.4387e-08,  4.6593e-08,  1.7877e-08,  2.4218e-08,  4.7231e-08,
#          6.8657e-08,  5.5444e-08,  2.1596e-07,  5.9052e-08,  7.2970e-08,
#          5.6073e-08,  1.5235e-08,  7.2274e-08,  3.4780e-08,  4.3065e-08,
#          1.6768e-08,  5.8173e-08,  3.1415e-08,  3.3191e-08,  4.3241e-08,
#          3.5170e-08,  2.8678e-08,  3.3779e-08,  3.3009e-08,  5.8700e-08,
#          3.2972e-08,  2.3121e-08,  1.1192e-07,  4.0972e-07,  3.5705e-07,
#          6.5652e-07,  7.9847e-08,  2.2913e-08,  2.3479e-08,  2.0693e-07,
#          1.3513e-07,  7.9219e-09,  9.6449e-10,  1.3510e-09,  3.2443e-10,
#          1.6956e-10,  1.3647e-10,  5.0015e-10,  3.3643e-09,  5.8508e-09,
#          5.5175e-08,  4.0117e-08,  2.6443e-08,  7.4948e-08,  3.5323e-08,
#          4.4566e-08,  4.9744e-08,  2.4847e-08,  9.9448e-08,  1.9692e-07,
#          2.0870e-06,  1.1440e-06,  6.2151e-06,  4.7699e-05,  1.0923e-05,
#          1.8140e-05,  7.4141e-06,  1.1647e-05,  2.1525e-05,  3.1604e-05,
#          1.4816e-06, -4.2898e-07,  4.7103e-09,  1.4944e-08,  7.7936e-10,
#          4.0797e-10,  2.4114e-10,  4.7659e-11,  3.8476e-10,  1.9655e-10,
#          1.4392e-09,  3.9057e-08,  4.2443e-08,  4.3500e-08,  5.5658e-08,
#          2.5694e-08,  1.2184e-07,  2.0774e-06,  8.1941e-06,  3.3204e-05,
#          6.1001e-05,  1.1132e-04,  1.4219e-04,  6.0339e-05,  7.9044e-05,
#          2.9238e-04,  2.8403e-04, -7.5481e-04, -1.7787e-03, -1.5010e-04,
#         -8.3129e-07,  4.1539e-08,  2.9774e-09,  2.6649e-10,  1.1686e-10,
#          3.5696e-11,  1.3676e-11,  6.7634e-11,  2.4962e-10,  1.7334e-09,
#          5.5040e-08,  2.1263e-08,  3.5664e-08,  6.9048e-08,  1.3885e-07,
#          1.4855e-05,  1.9033e-05,  5.6807e-05,  1.2774e-04,  1.5637e-04,
#          8.4713e-05,  1.3480e-04,  3.3271e-04,  9.1845e-04, -4.1189e-03,
#         -6.1274e-03, -9.4199e-03, -3.5702e-03, -8.5280e-05,  2.2206e-06,
#          5.3237e-08,  1.2769e-09,  8.7792e-11,  2.3821e-11,  5.0761e-11,
#          1.1610e-10,  5.7698e-11,  1.7920e-10,  2.1684e-09,  5.8252e-08,
#          2.7879e-08,  1.3126e-08,  2.0462e-06,  1.9356e-05,  3.6684e-05,
#          1.9581e-05,  3.0049e-05,  1.4782e-05,  1.1987e-05,  2.8385e-05,
#          1.2231e-04, -1.0468e-03, -5.9348e-03, -3.5915e-03, -2.4385e-03,
#          1.6561e-06,  6.1313e-08,  4.8968e-08,  3.8520e-08,  4.7803e-08,
#          1.0264e-08,  3.2196e-07,  1.7254e-06,  2.1068e-06,  5.6454e-06,
#          1.5464e-05,  5.9858e-05,  9.7502e-05,  1.0463e-04,  1.1398e-04,
#          1.0367e-04,  3.2129e-05,  7.5488e-06,  1.9446e-06,  2.3925e-07,
#          1.5582e-07,  4.0968e-07,  1.1810e-07,  8.2669e-08,  2.9528e-07,
#          4.5480e-07,  1.3374e-07,  6.4383e-07,  1.5011e-07,  2.7838e-08,
#          2.0957e-08,  6.1415e-08,  9.4550e-08,  4.0398e-09,  1.0694e-10,
#          5.1133e-09,  3.2703e-08,  4.6835e-08,  2.7273e-07,  2.1824e-06,
#          5.4691e-06,  2.7616e-06,  1.1356e-06,  7.1087e-07,  2.2562e-07,
#          6.5619e-08,  3.5610e-08,  8.6433e-09,  9.7399e-09,  8.2402e-08,
#          1.5933e-07,  1.3434e-07,  1.1741e-07,  7.4786e-08,  2.3298e-08,
#          1.4262e-07,  1.0944e-07,  6.0025e-08,  4.2444e-08,  2.0865e-08,
#          4.4830e-08,  4.2747e-08,  1.0534e-08,  4.0323e-09,  8.9728e-10,
#          1.1552e-08,  3.5212e-08,  7.2643e-08,  2.4883e-07,  7.3660e-08,
#          1.4226e-08,  3.5674e-08,  4.4830e-08,  3.9279e-08,  5.9871e-09,
#          3.6453e-09,  2.1647e-09,  9.6983e-10,  8.9776e-09,  7.2569e-08,
#          2.7483e-08,  1.3358e-07,  7.1603e-08,  3.3167e-08,  5.8285e-08,
#          3.6818e-08,  5.6857e-08,  3.0388e-08,  5.3728e-08,  3.5077e-08,
#          1.1840e-07,  5.8225e-08,  2.5487e-08,  4.4950e-09,  1.3231e-08,
#          1.9429e-08,  4.0652e-09,  9.1062e-09,  1.6444e-09,  3.4012e-10,
#          4.7219e-09,  3.2634e-08,  3.8491e-08,  3.7470e-09,  2.7370e-09,
#          8.6676e-10,  9.7464e-10,  4.9341e-08,  5.0775e-08,  1.5678e-07,
#          2.5017e-08,  2.7034e-08,  5.3463e-08,  5.4346e-08])

# %%
fig=plt.figure(figsize=(28, 28))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
    img = recon_images1[i-1].detach().numpy().reshape(28, 28)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img, cmap="gray")
plt.show()

# %%
with torch.no_grad():
    recon_images1 = []
    recon_images2 = []
    eps_val = torch.randn_like(mu1)
    for ctr in range(0, 100, 5):
        eps_val[7] = ctr * 0.05 * std1[7] + mu1[7]
        z_val1 = eps_val.mul(std1).add_(mu1)
        z_val2 = eps_val.mul(std2).add_(mu2)
        recon_image1 = model.decode(z_val1)
        recon_image2 = model.decode(z_val2)
        recon_images1.append(recon_image1)
        recon_images2.append(recon_image2)

# %%
fig=plt.figure(figsize=(28, 28))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
    img = recon_images1[i-1].detach().numpy().reshape(28, 28)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img, cmap="gray")
plt.show()

# %%
eps_any = torch.randn_like(mu1)
z1 = eps_any.mul(std1).add_(mu1)
z2 = eps_any.mul(std2).add_(mu2)
all_recons = []
for i in range(20):
    z_bet = z1 + torch.full_like(mu1, fill_value = 0.05*i).mul(z2 - z1)
    recon_image = model.decode(z_bet)
    all_recons.append(recon_image)

# %%
fig=plt.figure(figsize=(28, 28))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
    img = all_recons[i-1].detach().numpy().reshape(28, 28)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img, cmap="gray")
plt.show()
