# %% [markdown]
# # Variational Auto-Encoder without the KL Divergence Loss
#
# ## Importing required packages

# %%
import torch
from torch.autograd import Variable
import numpy as np
import torch.nn.functional as F
import torchvision
from torchvision import transforms
import torch.optim as optim
from torch import nn
import matplotlib.pyplot as plt

# %% [markdown]
# # Defining the model
#
# Model is same as that in [this notebook](https://github.com/ac-alpha/VAEs-using-Pytorch/blob/master/VAE_two_latent_variables.ipynb)
#
# <img src="Architecture_2_latent.png" width="800" />

# %%
class VAE(nn.Module):
  
    def __init__(self):
        super(VAE, self).__init__()
        
        self.fc1 = nn.Linear(28*28, 400)
        self.fc2_mu = nn.Linear(400, 2)
        self.fc2_sig = nn.Linear(400, 2)
        self.fc3 = nn.Linear(2, 400)
        self.fc4 = nn.Linear(400, 784)
  
    def encode(self,x):
        a1 = F.relu(self.fc1(x))
        a_mu = self.fc2_mu(a1)
        a_logvar = self.fc2_sig(a1)
        return a_mu, a_logvar
  
    def decode(self,z):
        a3 = F.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(a3))
  
    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return eps.mul(std).add_(mu)
  
    def forward(self,x):
        mu, logvar = self.encode(x.view(-1, 784))
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# %% [markdown]
# # Getting the Dataset

# %%
train_dataset = torchvision.datasets.MNIST(root='./data',train=True, transform=transforms.ToTensor(), download=True)
test_dataset = torchvision.datasets.MNIST(root='./data',train=False, transform=transforms.ToTensor(),download = True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,  batch_size=100, shuffle=False)

# %% [markdown]
# ## Instantiating the model and optimizer

# %%
model = VAE()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# ## Loss function
#
# Note that here we are not using the KL Divergence loss which tries to make the learned distribution similar to a known distribution.

# %%
def loss_function(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')

    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE #+ KLD

# %% [markdown]
# # Training

# %%
num_epochs = 5
print_per = 100
model.train()
for epoch in range(num_epochs):
    train_loss = 0
    print_loss = 0
    loss_record = []
    for i, (images, _) in enumerate(train_loader):
        images = images.reshape(-1, 28*28)
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(images)
        loss = loss_function(recon_batch, images, mu, logvar)
        loss.backward()
        train_loss += loss.item()
        print_loss += loss.item()
        optimizer.step()
        if (i%print_per == 0):
            print("Epoch : {} , Minibatch : {} Loss = {:.4f}".format(epoch+1, i, print_loss))
            loss_record.append(print_loss)
            print_loss = 0
    print("Epoch {} : Loss = ({:.4f}) ".format(epoch+1, train_loss))
# Out:
# Epoch : 1 , Minibatch : 0 Loss = 55285.2773
# Epoch : 1 , Minibatch : 100 Loss = 2177781.4355
# Epoch : 1 , Minibatch : 200 Loss = 1792924.7793
# Epoch : 1 , Minibatch : 300 Loss = 1735779.8027
# Epoch : 1 , Minibatch : 400 Loss = 1691697.7334
# Epoch : 1 , Minibatch : 500 Loss = 1660767.7100
# Epoch 1 : Loss = (10750138.2656)
# Epoch : 2 , Minibatch : 0 Loss = 17036.9980
# Epoch : 2 , Minibatch : 100 Loss = 1628866.8564
# Epoch : 2 , Minibatch : 200 Loss = 1615054.5918
# Epoch : 2 , Minibatch : 300 Loss = 1610399.7930
# Epoch : 2 , Minibatch : 400 Loss = 1603583.6377
# Epoch : 2 , Minibatch : 500 Loss = 1592360.5439
# Epoch 2 : Loss = (9637279.6738)
# Epoch : 3 , Minibatch : 0 Loss = 16066.4424
# Epoch : 3 , Minibatch : 100 Loss = 1579388.4619
# Epoch : 3 , Minibatch : 200 Loss = 1568634.6035
# Epoch : 3 , Minibatch : 300 Loss = 1571207.4902
# Epoch : 3 , Minibatch : 400 Loss = 1561196.9590
# Epoch : 3 , Minibatch : 500 Loss = 1561369.8438
# Epoch 3 : Loss = (9398501.1709)
# Epoch : 4 , Minibatch : 0 Loss = 14489.4082
# Epoch : 4 , Minibatch : 100 Loss = 1541110.0176
# Epoch : 4 , Minibatch : 200 Loss = 1549612.0859
# Epoch : 4 , Minibatch : 300 Loss = 1553852.9629
# Epoch : 4 , Minibatch : 400 Loss = 1539440.5146
# Epoch : 4 , Minibatch : 500 Loss = 1536792.6211
# Epoch 4 : Loss = (9254957.5498)
# Epoch : 5 , Minibatch : 0 Loss = 14611.3770
# Epoch : 5 , Minibatch : 100 Loss = 1523994.8613
# Epoch : 5 , Minibatch : 200 Loss = 1525037.9111
# Epoch : 5 , Minibatch : 300 Loss = 1527161.3271
# Epoch : 5 , Minibatch : 400 Loss = 1525567.0098
# Epoch : 5 , Minibatch : 500 Loss = 1521079.9834
# Epoch 5 : Loss = (9149651.3379)

# %%
print(model(images)[0].data[0].numpy().shape)
image1 = images[8]
print(image1.shape)
plt.imshow(model(images)[0].data[8].numpy().reshape(28, 28), cmap='gray')
plt.show(block=True)
# Out:
# (784,)
# torch.Size([784])

# %% [markdown]
# # Testing

# %%
test_loss = 0
print_per = 10
with torch.no_grad():
    for i, (images, _) in enumerate(test_loader):
        images = images.reshape(-1, 28*28)
        recon_batch, mu, logvar = model(images)
        test_loss += loss_function(recon_batch, images, mu, logvar).item()
        if (i%print_per == 0):
            plt.imshow(model(images)[0].data[0].numpy().reshape(28, 28), cmap='gray')
            plt.show(block=True)

# %%
image2 = images[1]
print(image2.shape)
# Out:
# torch.Size([784])

# %%
plt.imshow(model(images)[0].data[1].numpy().reshape(28, 28), cmap='gray')
plt.show(block=True)

# %%
plt.imshow(images[1].numpy().reshape(28, 28), cmap='gray')
plt.show(block=True)

# %% [markdown]
# # Experiments

# %%
with torch.no_grad():
    mu1, logvar1 = model.encode(image1)
    std1 = torch.exp(0.5*logvar1)
    mu2, logvar2 = model.encode(image2)
    std2 = torch.exp(0.5*logvar2)

# %%
with torch.no_grad():
    recon_images1 = []
    for ctr in range(0, 100, 5):
        eps_val = torch.full_like(mu1, fill_value = ctr * 0.01 )
        z_val1 = eps_val.mul(std1).add_(mu1)
        recon_image1 = model.decode(z_val1)
        recon_images1.append(recon_image1)

# %% [markdown]
# ### 6. Here we see that,  the values of z constructed the same image
#
# See other experiments [here](https://github.com/ac-alpha/VAEs-using-Pytorch/blob/master/VAE.ipynb) and [here](https://github.com/ac-alpha/VAEs-using-Pytorch/blob/master/VAE_two_latent_variables.ipynb)

# %%
print(recon_images1[0] - recon_images1[1])
# Out:
# tensor([-2.6586e-08, -2.8682e-08, -3.4881e-08, -2.9700e-08, -3.3273e-08,
#         -3.1752e-08, -2.5870e-08, -2.1513e-08, -3.2396e-08, -3.4332e-08,
#         -3.3804e-08, -2.9075e-08, -2.1610e-08, -3.2614e-08, -3.6518e-08,
#         -2.7005e-08, -3.9610e-08, -2.8274e-08, -2.7776e-08, -2.9446e-08,
#         -2.4385e-08, -3.2236e-08, -3.6365e-08, -3.4794e-08, -3.1767e-08,
#         -2.6535e-08, -1.9716e-08, -4.8840e-08, -3.1923e-08, -3.2185e-08,
#         -4.7392e-08, -2.8984e-08, -2.3743e-08, -2.8471e-08, -3.1720e-08,
#         -3.8643e-08, -7.1617e-08, -4.2332e-08, -2.8293e-08, -2.8616e-08,
#          7.8380e-06,  5.4240e-06,  1.0282e-06,  1.9325e-07,  2.0955e-08,
#         -2.5142e-08, -2.8345e-10, -1.5424e-09, -9.2965e-08, -2.9869e-07,
#         -2.4593e-07, -8.9451e-08, -3.4812e-08, -2.9784e-08, -3.3000e-08,
#         -2.7881e-08, -4.2008e-08, -4.0633e-08, -2.3292e-07, -9.0827e-07,
#         -4.1351e-06, -8.4341e-06, -1.1772e-05, -5.9232e-06, -1.4901e-07,
#          1.9372e-07,  1.4864e-06,  1.2703e-06,  2.6636e-07,  1.1455e-07,
#          7.0315e-08, -2.6543e-08, -1.2271e-08, -1.4180e-10, -1.0107e-10,
#         -6.6964e-10, -8.6334e-09, -6.9114e-08, -2.2535e-07, -8.0836e-08,
#         -4.2786e-08, -3.6234e-08, -3.2931e-08, -2.7234e-08, -2.9573e-08,
#         -3.5423e-08, -3.3458e-08, -6.9046e-07, -1.3746e-06, -1.5018e-06,
#         -1.3674e-06, -6.9593e-07, -3.9802e-07, -2.8999e-07, -1.8085e-07,
#         -4.5751e-08, -6.0536e-09,  4.1677e-08,  3.5623e-08, -3.5965e-08,
#         -1.5151e-10, -2.7228e-10, -5.4564e-10, -3.2358e-09, -2.2777e-08,
#         -9.4180e-08, -9.6959e-08, -3.3375e-08, -3.2975e-08, -2.4846e-08,
#         -3.6747e-08, -3.5092e-08, -2.2936e-08, -3.6511e-08, -2.3545e-08,
#         -5.2889e-08, -2.9820e-07, -2.3743e-07, -2.4546e-07, -1.1595e-07,
#         -7.0781e-08, -3.6263e-08, -7.5685e-08, -1.6797e-08, -1.0592e-08,
#         -1.0772e-08, -1.1471e-09, -3.6187e-10, -9.2541e-10, -3.7739e-09,
#         -1.2541e-08, -8.9145e-08, -4.0505e-08, -4.7661e-08, -3.4557e-08,
#         -3.3673e-08, -2.8318e-08, -2.3609e-08, -2.2577e-08])

# %%
fig=plt.figure(figsize=(28, 28))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
    img = recon_images1[i-1].detach().numpy().reshape(28, 28)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img, cmap="gray")
plt.show()

# %%
eps_any = torch.randn_like(mu1)
z1 = eps_any.mul(std1).add_(mu1)
z2 = eps_any.mul(std2).add_(mu2)
all_recons = []
for i in range(20):
    z_bet = z1 + torch.full_like(mu1, fill_value = 0.05*i).mul(z2 - z1)
    recon_image = model.decode(z_bet)
    all_recons.append(recon_image)

# %%
fig=plt.figure(figsize=(28, 28))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
    img = all_recons[i-1].detach().numpy().reshape(28, 28)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img, cmap="gray")
plt.show()

# %% [markdown]
# ### 7. Here in the scatter plot we see that the points belonging to a single digit are pretty far from one other. So, while transitioning from one digit to another in the latent space,  we will sample a lot of noise.

# %%
test_dataset = torchvision.datasets.MNIST(root='./data',train=False, transform=transforms.ToTensor(),download = True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,  batch_size=2000, shuffle=False)

# %%
x_set, y_set = next(iter(test_loader))
x_set = x_set.reshape(-1, 28*28)
z_set = model.encode(x_set)[0].detach().numpy()
color = y_set

# %%
plt.figure(figsize=(8,6))
plt.scatter(z_set[:, 0], z_set[:, 1], c=color, cmap = "viridis")
plt.colorbar()
plt.grid()
