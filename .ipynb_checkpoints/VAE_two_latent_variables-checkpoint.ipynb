# %%
import torch
from torch.autograd import Variable
import numpy as np
import torch.nn.functional as F
import torchvision
from torchvision import transforms
import torch.optim as optim
from torch import nn
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
class VAE(nn.Module):
  
    def __init__(self):
        super(VAE, self).__init__()
        
        self.fc1 = nn.Linear(28*28, 512)
        self.fc2_mu = nn.Linear(512, 2)
        self.fc2_sig = nn.Linear(512, 2)
        self.fc3 = nn.Linear(2, 512)
        self.fc4 = nn.Linear(512, 784)
  
    def encode(self,x):
        a1 = F.relu(self.fc1(x))
        a_mu = self.fc2_mu(a1)
        a_logvar = self.fc2_sig(a1)
        return a_mu, a_logvar
  
    def decode(self,z):
        a3 = F.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(a3))
  
    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return eps.mul(std).add_(mu)
  
    def forward(self,x):
        mu, logvar = self.encode(x.view(-1, 784))
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# %%
train_dataset = torchvision.datasets.MNIST(root='./data',train=True, transform=transforms.ToTensor(), download=True)
test_dataset = torchvision.datasets.MNIST(root='./data',train=False, transform=transforms.ToTensor(),download = True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,  batch_size=100, shuffle=False)

# %%
model = VAE()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
def loss_function(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')

    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD

# %%
num_epochs = 10
print_per = 100
model.train()
loss_record = []
for epoch in range(num_epochs):
    train_loss = 0
    print_loss = 0
    for i, (images, _) in enumerate(train_loader):
        images = images.reshape(-1, 28*28)
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(images)
        loss = loss_function(recon_batch, images, mu, logvar)
        loss.backward()
        if (epoch == 0):
            loss_record.append(loss.item())
        train_loss += loss.item()
        print_loss += loss.item()
        optimizer.step()
        
        if (i%print_per == 0):
            print("Epoch : {} , Minibatch : {} Loss = {:.4f}".format(epoch, i, print_loss))
#             loss_record.append(print_loss)
            print_loss = 0
    print("Epoch {} : Loss = ({:.4f}) ".format(epoch, train_loss))
# Out:
# Epoch : 0 , Minibatch : 0 Loss = 55043.3203
# Epoch : 0 , Minibatch : 100 Loss = 2200483.1621
# Epoch : 0 , Minibatch : 200 Loss = 1841042.9668
# Epoch : 0 , Minibatch : 300 Loss = 1790218.8105
# Epoch : 0 , Minibatch : 400 Loss = 1758076.2520
# Epoch : 0 , Minibatch : 500 Loss = 1724106.2910
# Epoch 0 : Loss = (11052699.5430)
# Epoch : 1 , Minibatch : 0 Loss = 17483.6816
# Epoch : 1 , Minibatch : 100 Loss = 1678005.6865
# Epoch : 1 , Minibatch : 200 Loss = 1673181.1699
# Epoch : 1 , Minibatch : 300 Loss = 1662793.9619
# Epoch : 1 , Minibatch : 400 Loss = 1653425.6113
# Epoch : 1 , Minibatch : 500 Loss = 1659434.6553
# Epoch 1 : Loss = (9963425.9404)
# Epoch : 2 , Minibatch : 0 Loss = 16369.9951
# Epoch : 2 , Minibatch : 100 Loss = 1632985.4121
# Epoch : 2 , Minibatch : 200 Loss = 1633866.2041
# Epoch : 2 , Minibatch : 300 Loss = 1628786.3184
# Epoch : 2 , Minibatch : 400 Loss = 1632006.8525
# Epoch : 2 , Minibatch : 500 Loss = 1626381.4707
# Epoch 2 : Loss = (9773361.3955)
# Epoch : 3 , Minibatch : 0 Loss = 16900.1035
# Epoch : 3 , Minibatch : 100 Loss = 1611327.1035
# Epoch : 3 , Minibatch : 200 Loss = 1613914.0684
# Epoch : 3 , Minibatch : 300 Loss = 1609192.1006
# Epoch : 3 , Minibatch : 400 Loss = 1612564.8125
# Epoch : 3 , Minibatch : 500 Loss = 1616056.7607
# Epoch 3 : Loss = (9663779.9629)
# Epoch : 4 , Minibatch : 0 Loss = 16851.6953
# Epoch : 4 , Minibatch : 100 Loss = 1592366.5527
# Epoch : 4 , Minibatch : 200 Loss = 1600802.0322
# Epoch : 4 , Minibatch : 300 Loss = 1593401.0205
# Epoch : 4 , Minibatch : 400 Loss = 1593124.5938
# Epoch : 4 , Minibatch : 500 Loss = 1594429.6924
# Epoch 4 : Loss = (9565138.5879)
# Epoch : 5 , Minibatch : 0 Loss = 15910.6211
# Epoch : 5 , Minibatch : 100 Loss = 1584672.3164
# Epoch : 5 , Minibatch : 200 Loss = 1577402.8848
# Epoch : 5 , Minibatch : 300 Loss = 1585383.6592
# Epoch : 5 , Minibatch : 400 Loss = 1582131.1260
# Epoch : 5 , Minibatch : 500 Loss = 1584332.5049
# Epoch 5 : Loss = (9483660.8750)
# Epoch : 6 , Minibatch : 0 Loss = 15864.7686
# Epoch : 6 , Minibatch : 100 Loss = 1566299.4072
# Epoch : 6 , Minibatch : 200 Loss = 1574448.3643
# Epoch : 6 , Minibatch : 300 Loss = 1568216.0869
# Epoch : 6 , Minibatch : 400 Loss = 1569956.9824
# Epoch : 6 , Minibatch : 500 Loss = 1570067.9395
# Epoch 6 : Loss = (9418625.7744)
# Epoch : 7 , Minibatch : 0 Loss = 15792.3018
# Epoch : 7 , Minibatch : 100 Loss = 1558909.6436
# Epoch : 7 , Minibatch : 200 Loss = 1561576.0439
# Epoch : 7 , Minibatch : 300 Loss = 1574841.9756
# Epoch : 7 , Minibatch : 400 Loss = 1550776.1748
# Epoch : 7 , Minibatch : 500 Loss = 1561394.8896
# Epoch 7 : Loss = (9365468.4541)
# Epoch : 8 , Minibatch : 0 Loss = 14975.0996
# Epoch : 8 , Minibatch : 100 Loss = 1554851.2549
# Epoch : 8 , Minibatch : 200 Loss = 1552735.2793
# Epoch : 8 , Minibatch : 300 Loss = 1553371.4873
# Epoch : 8 , Minibatch : 400 Loss = 1546246.8721
# Epoch : 8 , Minibatch : 500 Loss = 1556157.7637
# Epoch 8 : Loss = (9320533.6982)
# Epoch : 9 , Minibatch : 0 Loss = 14880.6113
# Epoch : 9 , Minibatch : 100 Loss = 1550685.3281
# Epoch : 9 , Minibatch : 200 Loss = 1552440.6016
# Epoch : 9 , Minibatch : 300 Loss = 1548760.9561
# Epoch : 9 , Minibatch : 400 Loss = 1541231.0938
# Epoch : 9 , Minibatch : 500 Loss = 1551623.3242
# Epoch 9 : Loss = (9282793.5479)

# %%
plt.plot(loss_record)

# %%
print(model(images)[0].data[0].numpy().shape)
image1 = images[8]
print(image1.shape)
plt.imshow(model(images)[0].data[8].numpy().reshape(28, 28), cmap='gray')
plt.show(block=True)
# Out:
# (784,)
# torch.Size([784])

# %%
test_loss = 0
print_per = 10
with torch.no_grad():
    for i, (images, _) in enumerate(test_loader):
        images = images.reshape(-1, 28*28)
        recon_batch, mu, logvar = model(images)
        test_loss += loss_function(recon_batch, images, mu, logvar).item()
        if (i%print_per == 0):
            plt.imshow(model(images)[0].data[0].numpy().reshape(28, 28), cmap='gray')
            plt.show(block=True)

# %%
image2 = images[1]
print(image2.shape)
# Out:
# torch.Size([784])

# %%
plt.imshow(model(images)[0].data[1].numpy().reshape(28, 28), cmap='gray')
plt.show(block=True)

# %%
plt.imshow(images[1].numpy().reshape(28, 28), cmap='gray')
plt.show(block=True)

# %%
with torch.no_grad():
    mu1, logvar1 = model.encode(image1)
    std1 = torch.exp(0.5*logvar1)
    mu2, logvar2 = model.encode(image2)
    std2 = torch.exp(0.5*logvar2)

# %%
n = 15
z1 = norm.ppf(np.linspace(0.01, 0.99, n))
z2 = norm.ppf(np.linspace(0.01, 0.99, n))

# %%
print(z1, z2)
# Out:
# [-2.32634787e+00 -1.40507156e+00 -1.03643339e+00 -7.72193214e-01
#  -5.53384720e-01 -3.58458793e-01 -1.76374165e-01 -1.39145821e-16
#   1.76374165e-01  3.58458793e-01  5.53384720e-01  7.72193214e-01
#   1.03643339e+00  1.40507156e+00  2.32634787e+00] [-2.32634787e+00 -1.40507156e+00 -1.03643339e+00 -7.72193214e-01
#  -5.53384720e-01 -3.58458793e-01 -1.76374165e-01 -1.39145821e-16
#   1.76374165e-01  3.58458793e-01  5.53384720e-01  7.72193214e-01
#   1.03643339e+00  1.40507156e+00  2.32634787e+00]

# %%
with torch.no_grad():
    recon_images1 = []
    for xi in z1 :
        for yi in z2 : 
            z_val = torch.zeros_like(mu1)
            z_val[0] = xi
            z_val[1] = yi
            recon_image = model.decode(z_val)
            recon_images1.append(recon_image)

# %%
fig=plt.figure(figsize=(28, 28))
columns = 15
rows = 15
for i in range(1, columns*rows +1):
    img = recon_images1[i-1].detach().numpy().reshape(28, 28)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img, cmap="gray")
plt.show()

# %%
test_dataset = torchvision.datasets.MNIST(root='./data',train=False, transform=transforms.ToTensor(),download = True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,  batch_size=2000, shuffle=False)

# %%
x_set, y_set = next(iter(test_loader))

# %%
z_set = model.encode(x_set)[0]

# %%
print(z_set.shape)
# Out:
# torch.Size([2000, 2])

# %%
color = np.argmax
